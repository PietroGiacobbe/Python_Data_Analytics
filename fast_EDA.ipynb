# %%
import pandas as pd
data = pd.read_csv("C:/Users/pietro.giacobbe/Desktop/Fast_EDA/Fortnite_Statistics.csv")
from fasteda import fast_eda
fast_eda(data)
# Out:
# DataFrame Head:
#    Date Time of Day  Placed Mental State  Eliminations  Assists  Revives  \
# 0  4/10     6:00 PM      27        sober             2        0        0
# 1  4/10     6:00 PM      45        sober             1        2        0
# 2  4/10     6:00 PM      38         high             3        0        0
#
#   Accuracy  Hits  Head Shots  Distance Traveled  Materials Gathered  \
# 0      23%    14           2             271.08                  20
# 1      30%    19           1             396.73                 123
# 2      30%    32           1             607.80                  71
#
#    Materials Used  Damage Taken  Damage to Players  Damage to Structures
# 0              20           272                331                   621
# 1              30           247                444                   998
# 2              60           176                322                  1109
# DataFrame Tail:
# ...

# %%
pip install fasteda
# Out:
# ...
#   Using cached fasteda-1.0.1.tar.gz (4.7 kB)
# ...
#   Using cached missingno-0.5.2-py3-none-any.whl (8.7 kB)
# ...
#   Created wheel for fasteda: filename=fasteda-1.0.1-py3-none-any.whl size=4740 sha256=75fd1c03eec656834e4b7029ae5bd5cbd1a521f3f178e92a60fd672ba262849b
#   Stored in directory: c:\users\pietro.giacobbe\appdata\local\pip\cache\wheels\93\57\7e\fdc4b9923cf3f1f46de4e2ea7a5a4acb335357f919920ffb7c
# Successfully built fasteda
# ...
# Note: you may need to restart the kernel to use updated packages.
